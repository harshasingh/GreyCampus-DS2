# %%
#import pandas library - for data manipulation and analysis.
import pandas as pd
# read data set and store it in data frame
cars=pd.read_csv("C:/Users/Admin/Desktop/DS - Varun/Pmat/data set/mtcars.csv")
#print output
cars
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#rename column
cars=cars.rename(columns={'Unnamed: 0' : 'model'})
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#fill in null values with mean of the column
cars.qsec=cars.qsec.fillna(cars.qsec.mean())
cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#drop unwanted column
#cars = cars.drop(columns=['S.No'])
#cars
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#find correlation matrix
df = cars[['mpg','cyl','disp','hp','wt','qsec','vs','am','gear','carb']].corr()
df
# Out:
#            mpg       cyl      disp        hp        wt      qsec        vs  \
# mpg   1.000000 -0.852162 -0.847551 -0.776168 -0.867659  0.418684  0.664039
# cyl  -0.852162  1.000000  0.902033  0.832447  0.782496 -0.591242 -0.810812
# disp -0.847551  0.902033  1.000000  0.790949  0.887980 -0.433698 -0.710416
# hp   -0.776168  0.832447  0.790949  1.000000  0.658748 -0.708223 -0.723097
# wt   -0.867659  0.782496  0.887980  0.658748  1.000000 -0.174716 -0.554916
# qsec  0.418684 -0.591242 -0.433698 -0.708223 -0.174716  1.000000  0.744535
# vs    0.664039 -0.810812 -0.710416 -0.723097 -0.554916  0.744535  1.000000
# am    0.599832 -0.522607 -0.591227 -0.243204 -0.692495 -0.229861  0.168345
# gear  0.480285 -0.492687 -0.555569 -0.125704 -0.583287 -0.212682  0.206023
# carb -0.550925  0.526988  0.394977  0.749812  0.427606 -0.656249 -0.569607
#
#             am      gear      carb
# mpg   0.599832  0.480285 -0.550925
# cyl  -0.522607 -0.492687  0.526988
# disp -0.591227 -0.555569  0.394977
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 12 columns):
# model    32 non-null object
# mpg      32 non-null float64
# cyl      32 non-null int64
# disp     32 non-null float64
# hp       32 non-null int64
# drat     32 non-null float64
# wt       32 non-null float64
# qsec     32 non-null float64
# vs       32 non-null int64
# am       32 non-null int64
# gear     32 non-null int64
# carb     32 non-null int64
# dtypes: float64(5), int64(6), object(1)
# memory usage: 3.1+ KB

# %%
#to view entire row & 4th column from DS [: is the row, 4 is the column no]
#we are viewing hp coulmn only
cars.iloc[:,4]
# Out:
# 0     110
# 1     110
# 2      93
# 3     110
# 4     175
# 5     105
# 6     245
# 7      62
# 8      95
# 9     123
# 10    123
# 11    180
# 12    180
# 13    180
# 14    205
# 15    215
# 16    230
# 17     66
# 18     52
# 19     65
# 20     97
# 21    150
# 22    150
# 23    245
# 24    175
# 25     66
# 26     91
# 27    113
# 28    264
# 29    175
# 30    335
# 31    109
# Name: hp, dtype: int64

# %%
#first 5 records of hp column
cars.iloc[0:5,4]
# Out:
# 0    110
# 1    110
# 2     93
# 3    110
# 4    175
# Name: hp, dtype: int64

# %%
#all rows, all cols
cars.iloc[:,:]
# Out:
#                   model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
#for attributes from hp to carb, to see all records from index 6
cars.iloc[6:,4:]
# Out:
#      hp  drat     wt   qsec  vs  am  gear  carb
# 6   245  3.21  3.570  15.84   0   0     3     4
# 7    62  3.69  3.190  20.00   1   0     4     2
# 8    95  3.92  3.150  22.90   1   0     4     2
# 9   123  3.92  3.440  18.30   1   0     4     4
# 10  123  3.92  3.440  18.90   1   0     4     4
# 11  180  3.07  4.070  17.40   0   0     3     3
# 12  180  3.07  3.730  17.60   0   0     3     3
# 13  180  3.07  3.780  18.00   0   0     3     3
# 14  205  2.93  5.250  17.98   0   0     3     4
# 15  215  3.00  5.424  17.82   0   0     3     4
# 16  230  3.23  5.345  17.42   0   0     3     4
# 17   66  4.08  2.200  19.47   1   1     4     1
# 18   52  4.93  1.615  18.52   1   1     4     2
# 19   65  4.22  1.835  19.90   1   1     4     1
# 20   97  3.70  2.465  20.01   1   0     3     1
# 21  150  2.76  3.520  16.87   0   0     3     2
# 22  150  3.15  3.435  17.30   0   0     3     2
# 23  245  3.73  3.840  15.41   0   0     3     4
# 24  175  3.08  3.845  17.05   0   0     3     2
# ...

# %%
#look at all the rows & only 1st column
cars.iloc[:,0]
# Out:
# 0               Mazda RX4
# 1           Mazda RX4 Wag
# 2              Datsun 710
# 3          Hornet 4 Drive
# 4       Hornet Sportabout
# 5                 Valiant
# 6              Duster 360
# 7               Merc 240D
# 8                Merc 230
# 9                Merc 280
# 10              Merc 280C
# 11             Merc 450SE
# 12             Merc 450SL
# 13            Merc 450SLC
# 14     Cadillac Fleetwood
# 15    Lincoln Continental
# 16      Chrysler Imperial
# 17               Fiat 128
# 18            Honda Civic
# 19         Toyota Corolla
# 20          Toyota Corona
# 21       Dodge Challenger
# 22            AMC Javelin
# 23             Camaro Z28
# 24       Pontiac Firebird
# 25              Fiat X1-9
# 26          Porsche 914-2
# 27           Lotus Europa
# 28         Ford Pantera L
# 29           Ferrari Dino
# 30          Maserati Bora
# 31             Volvo 142E
# Name: model, dtype: object

# %%
import pandas as pd
# read data set and store it in data frame
cars=pd.read_csv("C:/Users/Admin/Desktop/DS - Varun/Pmat/data set/mtcars.csv")
#see all record of mpg column
cars.loc[:,"mpg"]
# Out:
# 0     21.0
# 1     21.0
# 2     22.8
# 3     21.4
# 4     18.7
# 5     18.1
# 6     14.3
# 7     24.4
# 8     22.8
# 9     19.2
# 10    17.8
# 11    16.4
# 12    17.3
# 13    15.2
# 14    10.4
# 15    10.4
# 16    14.7
# 17    32.4
# 18    30.4
# 19    33.9
# 20    21.5
# 21    15.5
# 22    15.2
# 23    13.3
# 24    19.2
# 25    27.3
# 26    26.0
# 27    30.4
# 28    15.8
# 29    19.7
# 30    15.0
# 31    21.4
# Name: mpg, dtype: float64

# %%
#display records from index 0 to index 6 from mpg columns
cars.loc[:6,"mpg"]
# Out:
# 0    21.0
# 1    21.0
# 2    22.8
# 3    21.4
# 4    18.7
# 5    18.1
# 6    14.3
# Name: mpg, dtype: float64

# %%
#see 1st 7 records from mpg to qsec column
cars.loc[:6,"mpg":"qsec"]
# Out:
#     mpg  cyl   disp   hp  drat     wt   qsec
# 0  21.0    6  160.0  110  3.90  2.620  16.46
# 1  21.0    6  160.0  110  3.90  2.875  17.02
# 2  22.8    4  108.0   93  3.85  2.320  18.61
# 3  21.4    6  258.0  110  3.08  3.215  19.44
# 4  18.7    8  360.0  175  3.15  3.440  17.02
# 5  18.1    6  225.0  105  2.76  3.460  20.22
# 6  14.3    8  360.0  245  3.21  3.570  15.84

# %%
#data manipulation
#set data to 1 in all values of 'am' column
cars['am'] = 1
cars
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   1
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   1
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   1
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   1
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   1
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   1
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   1
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   1
# ...

# %%
f = lambda x: x*2
cars['am'] = cars['am'].apply(f)
cars
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   2
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   2
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   2
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   2
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   2
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   2
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   2
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   2
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   2
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   2
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   2
# ...

# %%
#sorting cyl in ascending order
cars.sort_values(by='cyl')
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 31           Volvo 142E  21.4    4  121.0  109  4.11  2.780  18.60   1   2
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   2
# 27         Lotus Europa  30.4    4   95.1  113  3.77  1.513  16.90   1   2
# 26        Porsche 914-2  26.0    4  120.3   91  4.43  2.140  16.70   0   2
# 25            Fiat X1-9  27.3    4   79.0   66  4.08  1.935  18.90   1   2
# 20        Toyota Corona  21.5    4  120.1   97  3.70  2.465  20.01   1   2
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   2
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   2
# 19       Toyota Corolla  33.9    4   71.1   65  4.22  1.835  19.90   1   2
# 18          Honda Civic  30.4    4   75.7   52  4.93  1.615  18.52   1   2
# 17             Fiat 128  32.4    4   78.7   66  4.08  2.200  19.47   1   2
# ...

# %%
#sorting cyl in descending order
cars.sort_values(by='cyl', ascending=False)
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   2
# 30        Maserati Bora  15.0    8  301.0  335  3.54  3.570  14.60   0   2
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   2
# 28       Ford Pantera L  15.8    8  351.0  264  4.22  3.170  14.50   0   2
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   2
# 24     Pontiac Firebird  19.2    8  400.0  175  3.08  3.845  17.05   0   2
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   2
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   2
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   2
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   2
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   2
# ...

# %%
#filter records with more than 6 cylinders

cars['cyl'] > 6
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
# 5     False
# 6      True
# 7     False
# 8     False
# 9     False
# 10    False
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17    False
# 18    False
# 19    False
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25    False
# 26    False
# 27    False
# 28     True
# 29    False
# 30     True
# 31    False
# Name: cyl, dtype: bool

# %%
#filter records with > 6 records
filters1 = cars['cyl'] > 6
#apply filters to data frme
filtered_new = cars[filters1]
#now view
filtered_new
# Out:
#              Unnamed: 0   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  \
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   2
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   2
# 11           Merc 450SE  16.4    8  275.8  180  3.07  4.070  17.40   0   2
# 12           Merc 450SL  17.3    8  275.8  180  3.07  3.730  17.60   0   2
# 13          Merc 450SLC  15.2    8  275.8  180  3.07  3.780  18.00   0   2
# 14   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0   2
# 15  Lincoln Continental  10.4    8  460.0  215  3.00  5.424  17.82   0   2
# 16    Chrysler Imperial  14.7    8  440.0  230  3.23  5.345  17.42   0   2
# 21     Dodge Challenger  15.5    8  318.0  150  2.76  3.520  16.87   0   2
# 22          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0   2
# 23           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0   2
# ...

# %%
#apply FILTER 
filter2 = (cars['cyl']>6) & (cars['hp']>300)
#apply filter to Data Frame
filtered_review = cars[filter2]
#dislay filtered view
filtered_review
# Out:
#        Unnamed: 0   mpg  cyl   disp   hp  drat    wt  qsec  vs  am  gear  carb
# 30  Maserati Bora  15.0    8  301.0  335  3.54  3.57  14.6   0   2     5     8

# %% [markdown]
# # Visualizing Data Set

# %%
#import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline 
#this is magic fn, causes plots to be shown as static images, only 1 call to %matplotlib inline is required.
# see how hp varies with each car in line plot
y1 = cars['hp']
x = range(32)
plt.plot(x,y1)

# %%
#import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
y1 = cars['hp']
y2 = cars['disp']
#see how both hp and disp vary
x = range(32)
plt.plot(x,y1)
plt.plot(x,y2)
plt.legend()

# %% [markdown]
# # Area plt

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
y1 = cars['hp']
y2 = cars['disp']
x = range(32)
#area plot
plt.stackplot(x,y1,colors='yellow', alpha=0.7)
plt.stackplot(x,y2,colors='black', alpha=0.2)

# %% [markdown]
# # Area & Line plot together

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
y1 = cars['hp']
y2 = cars['disp']
x = range(32)
#plt both - line plot & area plot to see the margin
plt.plot(x,y1,linewidth=2.0,color='C')
plt.stackplot(x,y1,colors='purple',alpha=0.7)
plt.plot(x,y2,linewidth=2.0,color='r')
plt.stackplot(x,y2,colors='black',alpha=0.5)
